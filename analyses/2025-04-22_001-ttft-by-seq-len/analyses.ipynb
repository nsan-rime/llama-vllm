# %% [markdown]
# ![alt text](2025-04-22_baseten-ttfb.png "Baseten TTFB")

# %%
import pandas as pd

results_df = pd.read_csv("/workspace/analyses/2025-04-22_001-ttft-by-seq-len/2025-04-22_001-ttft-by-seq-len.csv")

results_df
# Out:
#                 utt_id  time_to_first_token  prompt_ntokens  \
# 0    rime-ivr-eval-000                 12.0            19.0
# 1    rime-ivr-eval-001                 13.0            21.0
# 2    rime-ivr-eval-002                 11.0            10.0
# 3    rime-ivr-eval-003                 12.0             8.0
# 4    rime-ivr-eval-004                 12.0            20.0
# ..                 ...                  ...             ...
# 146  rime-ivr-eval-146                 12.0            46.0
# 147  rime-ivr-eval-147                 13.0            45.0
# 148  rime-ivr-eval-148                 13.0            34.0
# 149  rime-ivr-eval-149                 13.0            35.0
# 150  rime-ivr-eval-150                 13.0            31.0
#
#      inter_token_duration  time_to_last_token
# 0                     7.0              2197.0
# 1                     7.0              2748.0
# 2                     7.0              1114.0
# 3                     7.0               670.0
# ...

# %%
import seaborn as sns

sns.scatterplot(data=results_df, x="prompt_ntokens", y="time_to_first_token")
# Out:
# <Axes: xlabel='prompt_ntokens', ylabel='time_to_first_token'>

# %%
sns.scatterplot(data=results_df, x="prompt_ntokens", y="time_to_last_token")
# Out:
# <Axes: xlabel='prompt_ntokens', ylabel='time_to_last_token'>
